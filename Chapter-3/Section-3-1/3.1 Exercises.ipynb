# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import output, drive

drive.mount('/content/gdrive/')
images_dir = '/content/gdrive/MyDrive/Colab_Notebooks/Wackerly/Chapter3/figures/Sec3_1/'
# %matplotlib inline
# Out:
# Mounted at /content/gdrive/

# %%
##### Problem 3.9
plt.clf()
# %clear
output.clear()

### Problem 3.9b
Y = np.array([(0.95)**3, 3 * ((0.95) ** 2) * (0.05), 3 * (0.95) * ((0.05) ** 2), (0.05) ** 3])

plt.bar(np.arange(4), Y, width=0.5, tick_label = np.arange(4),facecolor = '#2ab0ff', edgecolor='#169acf')

plt.title('Probability Histogram if Accounting Errors') 
plt.xlabel('# Errors') 
plt.ylabel('Probability')

plt.savefig(f'{images_dir}/3_9_b.png')
plt.show()
