# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import binom, poisson
from google.colab import output, drive

drive.mount('/content/gdrive/')
images_dir = '/content/gdrive/MyDrive/Colab_Notebooks/Wackerly/Chapter3/figures/Sec3_10/'
# %matplotlib inline
# Out:
# Mounted at /content/gdrive/

# %%
##### Problem 3.168
plt.clf()
# %clear
output.clear()

### Problem 3.168a
prob = 1

for y in np.arange(50):
  prob -= binom.pmf(y, 100, 0.2, 0)

print(f'Probability of passing: {prob}')
# Out:
# Probability of passing: 2.141104446987819e-11
