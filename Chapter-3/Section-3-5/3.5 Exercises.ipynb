# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import geom
from google.colab import output, drive

drive.mount('/content/gdrive/')
images_dir = '/content/gdrive/MyDrive/Colab_Notebooks/Wackerly/Chapter3/figures/Sec3_5/'
# %matplotlib inline
# Out:
# Mounted at /content/gdrive/

# %%
##### Problem 3.70
plt.clf()
# %clear
output.clear()

### Problem 3.70b
sum = 0

for y in np.arange(1, 11):
  sum += geom.pmf(y, 0.2, 0)

print(f'Probability the prospector fails to find a prospective well: {1 - sum:.4f}')
# Out:
# Probability the prospector fails to find a prospective well: 0.1074

# %%
##### Problem 3.70
plt.clf()
# %clear
output.clear()
### Problem 3.70b
sum = 0

for y in np.arange(1, 6):
  sum += geom.pmf(y, 0.6, 0)

print(f'Probability at least 6 people must be interviewed: {1 - sum:.4f}')
# Out:
# Probability at least 6 people must be interviewed: 0.0102
