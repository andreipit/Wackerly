# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import output, drive

drive.mount('/content/gdrive/')
images_dir = '/content/gdrive/MyDrive/Colab_Notebooks/Wackerly/Chapter3/figures/Sec3_3/'
# %matplotlib inline
# Out:
# Mounted at /content/gdrive/

# %%
##### Problem 3.15
plt.clf()
# %clear
output.clear()

### Problem 3.15b
y = np.arange(4)
p_y = np.array([.48 ** 3, 3 * 0.52 * (0.48 ** 2), 3 * (0.52 ** 2) * 0.48, 0.52 ** 3])

plt.bar(y, p_y, width=0.5, tick_label = np.arange(4),facecolor = '#2ab0ff', edgecolor='#169acf')

plt.title('Probability Histogram of Late Night TV Fans') 
plt.xlabel('# Prefer Jared Ledo') 
plt.ylabel('Frequency')

plt.savefig(f'{images_dir}/3_15_b.png')
plt.show()
